# %%
#Import dataset

# %%
#Schema discovery

# %%
#Data quality assessment
#missing values per column

# %%
#Validity
#check for impossible values (e.g. negative polution, extreme outliers
#unit inconsistencies
#timestamps outside expected ranges
#duplicated rows

# %%
#Consistency
#naming conventions uniform
#dates uniform

# %%
#Class distribution
#Examine how often rain today equals yes and no
#Flag potential class imbalances
